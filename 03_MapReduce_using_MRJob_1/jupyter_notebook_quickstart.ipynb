# %% [markdown]
# # Jupyter Notebook Quick Start

# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %% [markdown]
# To run a bash command, add `!` in front of your command:

# %%
# !pwd
# Out:
# /home/hadoop/Workspace/03_MapReduce_using_MRJob_1

# %%
# !ls ../data/
# Out:
# job-data  state-db  students.csv  wordCount_input

# %% [markdown]
# To create/modify a file, add `%%file <filename>` to the first line of the cell:

# %%
# %%file mrjob_test.txt
# from mrjob.job import MRJob
#
#
# class MRWordCount(MRJob):
#
#     def mapper(self, _, line):
#         words = line.strip().split()
#         for word in words:
#             yield word, 1
#
#     def reducer(self, key, values):
#         yield key, sum(values)
#
#
# if __name__ == '__main__':
#     MRWordCount.run()
# Out:
# Writing mrjob_test.txt

# %% [markdown]
# Now we can run the Python script `mrjob_test.txt` via bash command:

# %%
# !python3 mrjob_test.txt ../data/wordCount_input/*
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Running step 1 of 1...
# Creating temp directory /tmp/mrjob_test.hadoop.20180925.202918.060258
# job output is in /tmp/mrjob_test.hadoop.20180925.202918.060258/output
# Streaming final output from /tmp/mrjob_test.hadoop.20180925.202918.060258/output...
# "quis,"	170
# "quis."	102
# "rhoncus"	408
# "rhoncus,"	67
# "rhoncus."	134
# "ridiculus"	82
# "risus"	722
# "risus,"	181
# "risus."	149
# "rutrum"	544
# "rutrum,"	33
# "rutrum."	67
# "sagittis"	554
# "sagittis,"	34
# "sagittis."	169
# "sapien"	450
# "sapien,"	183
# "sapien."	152
# "scelerisque"	556
# "scelerisque,"	33
# "scelerisque."	85
# "sed"	1516
# "sed,"	185
# "sed."	136
# "sem"	667
# "sem,"	150
# "sem."	253
# "semper"	389
# "semper,"	66
# "semper."	98
# "senectus"	185
# "sit"	2105
# "sociis"	82
# "sociosqu"	136
# "sodales"	418
# "sodales,"	16
# "sodales."	100
# "sollicitudin"	374
# "sollicitudin,"	52
# "sollicitudin."	133
# ...
